# %%
import pandas as pd

# %%
import json

# %%
f = open('apidata.json')

# %%
data = json.load(f)

# %%
a = pd.DataFrame.from_dict(data, orient='index')

# %%
a.to_csv('bookscsv.csv')

# %%
a
# Out:
#                                                    error  \
# 2020 Practices of the Python Pro.pdf                   0
# 2021 Robust Python.pdf                                 0
# 2015 Python Unlocked.pdf                               0
# 2022 Mastering Python.pdf                              0
# 2022 Fluent Python.pdf                                 0
# 2021 Expert Python Programming.pdf                     0
# 2022 Python Architecture Patterns2.pdf                 0
# 2020 Using Asyncio in Python.pdf                       0
# 2020 Architecture Patterns with Python.pdf             0
# 2022 Python Concurrency with asyncio.pdf               0
# 2018 Clean Code in Python.pdf                          0
# 2019 Python Continuous Integration and Delivery...     0
# 2022 Advanced Python Programming.pdf                   0
# 2021 BEYOND THE BASIC STUFF WITH PYTHON.pdf            0
# 2022 Python Architecture Patterns packt.pdf            0
#
# ...

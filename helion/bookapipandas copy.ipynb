# %%
import pandas as pd

# %%
import json

# %%
f = open('checkyearapidata.json')

# %%
data = json.load(f)

# %%
a = pd.DataFrame.from_dict(data, orient='index')

# %%
a.to_csv('checkyear.csv')

# %%
a
# Out:
#                                                    error  \
# 1997 Writing GNU Emacs Extensions.pdf                  0
# 2006 Head First HTML with CSS & XHTML.pdf              0
# 2009 JavaScript - mocne strony - Douglas Crockf...     0
# 2011 Programming Python.pdf                            0
# 2012 C++ Primer Plus.pdf                               0
# ...                                                  ...
# 2022 Street Coder.pdf                                  0
# 2023 Modern System Administration.pdf                  0
# 2023 Python Data Science Handbook.pdf                  0
# 2023 Quick JavaScript.pdf                              0
# 2023 Rust Web Development.pdf                          0
#
#                                                                                         title  \
# 1997 Writing GNU Emacs Extensions.pdf                              GNU Emacs Pocket Reference
# ...
